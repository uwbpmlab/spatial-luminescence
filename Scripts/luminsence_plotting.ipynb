# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Glucose/48HRMedia.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='viridis')
plt.title('Glucose Assay: 48hr Media')
plt.show()

# %%
# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values
#print(x, y)

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Reshape the z values to match the shape of the meshgrid
#z_grid = z.reshape(x_grid.shape)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x_grid, y_grid, z, cmap = 'viridis', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Glucose Assay: 48hr Media')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Viability/day0viability.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='viridis')
plt.title('Viability Assay: Day 0')
plt.show()

# %%
# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values
#print(x, y)

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Reshape the z values to match the shape of the meshgrid
#z_grid = z.reshape(x_grid.shape)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x_grid, y_grid, z, cmap = 'viridis', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Viability Assay: Day 0')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Viability/day3viability.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='viridis')
plt.title('Viability Assay: Day 3')
plt.show()

# %%
# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values
#print(x, y)

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Reshape the z values to match the shape of the meshgrid
#z_grid = z.reshape(x_grid.shape)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x_grid, y_grid, z, cmap = 'viridis', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Viability Assay: Day 3')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Glucose/24HRMedia.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='viridis')
plt.title('Glucose Assay: 24hr Media')
plt.show()

# %%
# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values
#print(x, y)

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Reshape the z values to match the shape of the meshgrid
#z_grid = z.reshape(x_grid.shape)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x_grid, y_grid, z, cmap = 'viridis', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Glucose Assay: 24hr Media')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Glucose/72HRMedia.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='viridis')
plt.title('Glucose Assay: 72hr Media')
plt.show()

# %%
# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values
#print(x, y)

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Reshape the z values to match the shape of the meshgrid
#z_grid = z.reshape(x_grid.shape)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x_grid, y_grid, z, cmap = 'viridis', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Glucose Assay: 72hr Media')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Lactate/24HRGelDirect.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='viridis')
plt.title('Lactate Assay: 24hr Gel Direct')
plt.show()
