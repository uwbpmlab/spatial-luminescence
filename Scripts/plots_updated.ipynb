# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Glucose/OldGlucoseData/24hr_gluc.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='inferno')
plt.title('Glucose Assay: 1hr Media')
plt.show()

# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values
#print(x, y)

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Reshape the z values to match the shape of the meshgrid
#z_grid = z.reshape(x_grid.shape)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x_grid, y_grid, z, cmap = 'inferno', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Glucose 1hr Media')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Glucose/OldGlucoseData/48hr_gluc.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='inferno')
plt.title('Glucose Assay: 48hr Media')
plt.show()

# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values
#print(x, y)

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Reshape the z values to match the shape of the meshgrid
#z_grid = z.reshape(x_grid.shape)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x_grid, y_grid, z, cmap = 'inferno', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Glucose Assay: 48hr Media')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Glucose/OldGlucoseData/72hr_gluc.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='inferno')
plt.title('Glucose 72hr Media')
plt.show()

# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values
#print(x, y)

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Reshape the z values to match the shape of the meshgrid
#z_grid = z.reshape(x_grid.shape)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x_grid, y_grid, z, cmap = 'inferno', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Glucose 72hr Media')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Glucose/NewGlucoseData/24hrs_media_100.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='inferno')
plt.title('Redone Glucose Assay: 1hr Media')
plt.show()

# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values
#print(x, y)

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Reshape the z values to match the shape of the meshgrid
#z_grid = z.reshape(x_grid.shape)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x_grid, y_grid, z, cmap = 'inferno', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Redone Glucose Assay: 1hr Media')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd
from scipy.ndimage import uniform_filter

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Glucose/NewGlucoseData/0hr_gluc_6_4_redone.csv')

sns.heatmap(data, cmap='inferno')
plt.title('Redone Glucose Assay: 1hr Media')
plt.show()


# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values

# Apply moving average smoothing
smoothed_z = uniform_filter(z, size=3)  # Adjust the size parameter for different levels of smoothing

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the smoothed surface
ax.plot_surface(x_grid, y_grid, smoothed_z, cmap='inferno', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Smoothed Redone Glucose Assay: 1hr Media')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import seaborn as sns
import pandas as pd
from scipy.ndimage import uniform_filter

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Lactate/6_3_Lactate_1_WELL_arranged_csv.csv')


sns.heatmap(data, cmap='inferno')
plt.title('Lactate 1')
plt.show()

# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Create a figure and subplot for the plots
fig = plt.figure()
ax1 = fig.add_subplot(121, projection='3d')  # Subplot 1 for the original surface plot
ax2 = fig.add_subplot(122, projection='3d')  # Subplot 2 for the smoothed surface plot

# Plot the original surface
ax1.plot_surface(x_grid, y_grid, z, cmap='inferno', antialiased=True)
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
ax1.set_title('Lactate 1')

# Apply moving average smoothing
smoothed_z = uniform_filter(z, size=5)  # Adjust the size parameter for different levels of smoothing

# Plot the smoothed surface
ax2.plot_surface(x_grid, y_grid, smoothed_z, cmap='inferno', antialiased=True)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')
ax2.set_title('Lactate 1')

# Adjust the layout to make room for both subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import pandas as pd
from scipy.ndimage import uniform_filter1d

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Glucose/NewGlucoseData/0hr_gluc_6_4_redone.csv')

# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values

# Apply moving average smoothing in the x direction
smoothed_z = uniform_filter(z, size=3)  # Adjust the size parameter for different levels of smoothing

smoothed_x_z = uniform_filter1d(z, size=3, axis=1)
# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Create a figure and subplot for the plots
fig = plt.figure()
ax1 = fig.add_subplot(121, projection='3d')  # Subplot 1 for the original surface plot
ax2 = fig.add_subplot(122, projection='3d')  # Subplot 2 for the smoothed surface plot

# Plot the original surface
ax1.plot_surface(x_grid, y_grid, smoothed_z, cmap='inferno', antialiased=True)
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
ax1.set_title('Smoothed Redone Glucose Assay: 1hr')

# Plot the smoothed surface
ax2.plot_surface(x_grid, y_grid, smoothed_x_z, cmap='inferno', antialiased=True)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')
ax2.set_title('Smoothed Redone Glucose Assay: 1hr smoothed in x')

# Adjust the layout to make room for both subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import seaborn as sns
import pandas as pd
from scipy.ndimage import uniform_filter

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Viability/day0viability.csv')


sns.heatmap(data, cmap='inferno')
plt.title('Viability Day 0')
plt.show()

# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Create a figure and subplot for the plots
fig = plt.figure()
ax1 = fig.add_subplot(121, projection='3d')  # Subplot 1 for the original surface plot
ax2 = fig.add_subplot(122, projection='3d')  # Subplot 2 for the smoothed surface plot

# Plot the original surface
ax1.plot_surface(x_grid, y_grid, z, cmap='inferno', antialiased=True)
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
ax1.set_title('Viability Day 0')

# Apply moving average smoothing
smoothed_z = uniform_filter(z, size=3)  # Adjust the size parameter for different levels of smoothing

# Plot the smoothed surface
ax2.plot_surface(x_grid, y_grid, smoothed_z, cmap='inferno', antialiased=True)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')
ax2.set_title('Viability Day 0')

# Adjust the layout to make room for both subplots
plt.tight_layout()

# Display the plot
plt.show()



data2 = pd.read_csv('C:/Users/HP/Documents/Python/Research/Viability/day3viability.csv')


sns.heatmap(data2, cmap='inferno')
plt.title('Viability Day 3')
plt.show()

# Extract the x, y, and z values from the data
y = list(range(1, len(data2) + 1))
x = list(range(1, len(data2.columns) + 1))
x = np.flip(x)
z = data2.values

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Create a figure and subplot for the plots
fig = plt.figure()
ax1 = fig.add_subplot(121, projection='3d')  # Subplot 1 for the original surface plot
ax2 = fig.add_subplot(122, projection='3d')  # Subplot 2 for the smoothed surface plot

# Plot the original surface
ax1.plot_surface(x_grid, y_grid, z, cmap='inferno', antialiased=True)
ax1.set_xlabel('X')
ax1.set_ylabel('Y')
ax1.set_zlabel('Z')
ax1.set_title('Viability Day 3')

# Apply moving average smoothing
smoothed_z = uniform_filter(z, size=3)  # Adjust the size parameter for different levels of smoothing

# Plot the smoothed surface
ax2.plot_surface(x_grid, y_grid, smoothed_z, cmap='inferno', antialiased=True)
ax2.set_xlabel('X')
ax2.set_ylabel('Y')
ax2.set_zlabel('Z')
ax2.set_title('Viability Day 3')

# Adjust the layout to make room for both subplots
plt.tight_layout()

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Viability/viability_6_3_t1hr.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='inferno')
plt.title('Viability 1hr')
plt.show()

# Extract the x, y, and z values from the data
y = list(range(1, len(data) + 1))
x = list(range(1, len(data.columns) + 1))
x = np.flip(x)
z = data.values
#print(x, y)

# Create a meshgrid for the x and y values
x_grid, y_grid = np.meshgrid(x, y)

# Reshape the z values to match the shape of the meshgrid
#z_grid = z.reshape(x_grid.shape)

# Create a 3D plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot the surface
ax.plot_surface(x_grid, y_grid, z, cmap = 'inferno', antialiased=True)

# Set labels and title
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.title('Viability t0')

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Viability/viability_6_4_t72hr.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='inferno')
plt.title('Viability 72hr')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Lactate/6_3_Lactate_1_WELL_arranged_csv.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='inferno')
plt.title('Lactate 1hr')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Lactate/6-4-23_Lactate-100pts-72hrs_CSV.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='inferno')
plt.title('Lactate 72hr')
plt.show()

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
import numpy as np
import pandas as pd
import seaborn as sns

# Load the data from the CSV file
data = pd.read_csv('C:/Users/HP/Documents/Python/Research/Viability/hct_viability_arranged_csv.csv')
# rows_to_read = list(range(20,35))
# selected_rows = data.iloc[rows_to_read]

#print(data)

sns.heatmap(data, cmap='inferno')
plt.title('Viability')
plt.show()
